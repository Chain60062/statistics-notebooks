# %%
import pandas as pd

data = {
    "Carrier": [23.02],
    "ATC": [30.40],
    "Weather": [4.03],
    "Security": [0.12],
    "Inbound": [42.43]
}

df = pd.DataFrame(data)

ax = df.transpose().plot.bar(figsize=(4,4), legend=False)
ax.set_xlabel('Cause of delay')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
